# %%
# A process is an instance of a computer program
# process runs parallely on multiple processors >> multiprocessing
# process run concurrently on multiple threads is a processor>>multithreading

# %%
import time
start=time.perf_counter()

def test_func():
    print("Do Something")
    print("Sleep for 1 sec")
    time.sleep(1)
    print("done with sleeping")

test_func()
end=time.perf_counter()
print(f"The program finished in {round(end-start,2)} seconds")
# Out:
# Do Something
# Sleep for 1 sec
# done with sleeping
# The program finished in 1.0 seconds

# %%
import time
start=time.perf_counter()

def test_func():
    print("Do Somethings")
    print("Sleep for 1 sec")
    time.sleep(1)
    print("Done with sleeping")

test_func()
test_func()
test_func()
test_func()
test_func()
end=time.perf_counter()
print(f"The program finished in {round(end-start,2)} seconds")
# Out:
# Do Somethings
# Sleep for 1 sec
# Done with sleeping
# Do Somethings
# Sleep for 1 sec
# Done with sleeping
# Do Somethings
# Sleep for 1 sec
# Done with sleeping
# Do Somethings
# Sleep for 1 sec
# Done with sleeping
# Do Somethings
# Sleep for 1 sec
# Done with sleeping
# The program finished in 5.0 seconds

# %%
# since the program run squentially(single thread on a single core),so it took 5 seconds.

# %%
import time
import threading # python module
start=time.perf_counter()

def test_func():
    print("Do Somethings")
    print("Sleep for 1 sec")
    time.sleep(1)
    print("Done with sleeping")

# run the program on two threads
t1=threading.Thread(target=test_func)
t2=threading.Thread(target=test_func)

t1.start()
t2.start()

t1.join() # join first executed these t1,t2 threads and then the main thread will be executed.
t2.join()

end=time.perf_counter()
print(f"The program finished in {round(end - start, 2)} seconds")
# Out:
# Do Somethings
# Sleep for 1 sec
# Do Somethings
# Sleep for 1 sec
# Done with sleeping
# Done with sleeping
# The program finished in 1.01 seconds
