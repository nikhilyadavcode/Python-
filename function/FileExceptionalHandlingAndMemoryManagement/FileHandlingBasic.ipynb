# %%
# mode
# r >> read mode
# w>> write mode
# a>> append mode
# r+>> both reading and writing

# %%
open("files.txt",'r') # if there is no any file, and you open it in read mode it will throw an error

# %%
open("file.txt","w") #w>>write mode,if a file is not there it will create the file.txt and then read it.
# Out:
# <_io.TextIOWrapper name='file.txt' mode='w' encoding='cp1252'>
