# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook
# Out:
# <function bokeh.io.output.output_notebook(resources: 'Resources | None' = None, verbose: 'bool' = False, hide_banner: 'bool' = False, load_timeout: 'int' = 5000, notebook_type: 'NotebookType' = 'jupyter') -> 'None'>

# %%
from bokeh.sampledata.iris import flowers
from bokeh.plotting import figure,output_file,show

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
from bokeh.sampledata.iris import flowers
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

output_notebook()

p = figure(title="test_flower")
p.xaxis.axis_label = "petal_length"
p.yaxis.axis_label = "petal_width"

p.circle(flowers["petal_length"], flowers["petal_width"], size=10) # circle for scatter plot

show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a310332c-d59d-4208-a47d-cc8a07079aed">Loading BokehJS ...</span>
#     </div>
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
#   <div id="ca2cab97-189d-434a-a24d-a747d47d6234" data-root-id="p1463" style="display: contents;"></div>

# %%
from bokeh.sampledata.iris import flowers
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

output_notebook()

p = figure(title="test_flower")
p.xaxis.axis_label = "petal_length"
p.yaxis.axis_label = "petal_width"

p.line(flowers["petal_length"], flowers["petal_width"], size=10) # circle for scatter plot

show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a5708e98-2817-47b1-a9e4-1bc2f1603fd7">Loading BokehJS ...</span>
#     </div>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 11
#       8 p.xaxis.axis_label = "petal_length"
#       9 p.yaxis.axis_label = "petal_width"
# ---> 11 p.line(flowers["petal_length"], flowers["petal_width"], size=10) # circle for scatter plot
#      13 show(p)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\bokeh\plotting\_decorators.py:88, in glyph_method.<locals>.decorator.<locals>.wrapped(self, *args, **kwargs)
#      86 if self.coordinates is not None:
#      87     kwargs.setdefault("coordinates", self.coordinates)
# ---> 88 return create_renderer(glyphclass, self.plot, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\bokeh\plotting\_renderer.py:119, in create_renderer(glyphclass, plot, **kwargs)
#     116 # handle the mute glyph, we always set one
#     117 muted_visuals = pop_visuals(glyphclass, kwargs, prefix='muted_', defaults=glyph_visuals, override_defaults={'alpha':0.2})
# --> 119 glyph = make_glyph(glyphclass, kwargs, glyph_visuals)
#     120 nonselection_glyph = make_glyph(glyphclass, kwargs, nonselection_visuals)
#     121 selection_glyph = make_glyph(glyphclass, kwargs, selection_visuals)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\bokeh\plotting\_renderer.py:147, in make_glyph(glyphclass, kws, extra)
#     145 kws = kws.copy()
#     146 kws.update(extra)
# --> 147 return glyphclass(**kws)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\bokeh\models\glyphs.py:985, in Line.__init__(self, *args, **kwargs)
#     984 def __init__(self, *args: Any, **kwargs: Any) -> None:
# --> 985     super().__init__(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\bokeh\models\glyph.py:110, in ConnectedXYGlyph.__init__(self, *args, **kwargs)
#     109 def __init__(self, *args: Any, **kwargs: Any) -> None:
# --> 110     super().__init__(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\bokeh\models\glyph.py:88, in XYGlyph.__init__(self, *args, **kwargs)
#      87 def __init__(self, *args: Any, **kwargs: Any) -> None:
# ---> 88     super().__init__(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\bokeh\models\glyph.py:66, in Glyph.__init__(self, *args, **kwargs)
#      65 def __init__(self, *args: Any, **kwargs: Any) -> None:
# ---> 66     super().__init__(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\bokeh\model\model.py:119, in Model.__init__(self, *args, **kwargs)
#     116 if "id" in kwargs:
#     117     raise ValueError("initializing 'id' is not allowed")
# --> 119 super().__init__(**kwargs)
#     120 default_theme.apply_to_model(self)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\bokeh\models\glyph.py:120, in LineGlyph.__init__(self, *args, **kwargs)
#     119 def __init__(self, *args: Any, **kwargs: Any) -> None:
# --> 120     super().__init__(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\bokeh\core\has_props.py:305, in HasProps.__init__(self, **properties)
#     303     if value is Undefined or value is Intrinsic:
#     304         continue
# --> 305     setattr(self, name, value)
#     307 initialized = set(properties.keys())
#     308 for name in self.properties(_with_props=True): # avoid set[] for deterministic behavior
#
# File ~\AppData\Roaming\Python\Python313\site-packages\bokeh\core\has_props.py:343, in HasProps.__setattr__(self, name, value)
#     340 if isinstance(descriptor, property): # Python property
#     341     return super().__setattr__(name, value)
# --> 343 self._raise_attribute_error_with_matches(name, properties)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\bokeh\core\has_props.py:378, in HasProps._raise_attribute_error_with_matches(self, name, properties)
#     375 if not matches:
#     376     matches, text = sorted(properties), "possible"
# --> 378 raise AttributeError(f"unexpected attribute {name!r} to {self.__class__.__name__}, {text} attributes are {nice_join(matches)}")
#
# AttributeError: unexpected attribute 'size' to Line, possible attributes are decorations, js_event_callbacks, js_property_callbacks, line_alpha, line_cap, line_color, line_dash, line_dash_offset, line_join, line_width, name, subscribed_events, syncable, tags, x or y

# %%
x=[1,2,3,4]
y=[3,8,4,7]

p=figure(title="line_chart")
p.line(x,y)
show(p)
# Out:
#   <div id="ec8b42fe-d4d1-4c99-823e-4287cb460ca8" data-root-id="p1626" style="display: contents;"></div>

# %%
x=[1,2,3,4]
y=[3,8,4,7]

p=figure(title="line_chart")
p.scatter(x,y,size=20,fill_color="red",legend_label="This is my data")
show(p)
# Out:
#   <div id="e4666f38-2880-4589-be94-fffda0118135" data-root-id="p1674" style="display: contents;"></div>
